# %% [markdown]
# #### Functions in Python
# Video Outline:
# 1. Introduction to Functions
# 2. Defining Functions
# 3. Calling Functions
# 4. Function Parameters
# 5. Default Parameters
# 6. Variable-Length Arguments
# 7. Return Statement

# %% [markdown]
# ##### Introduction to Functions
# Definition:
#
# A function is a block of code that performs a specific task.
# Functions help in organizing code, reusing code, and improving readability.

# %%
## syntax
def function_name(parameters):
    """Docstring"""
    # Function body
    return #expression

# %%
## why functions?
num=24
if num%2==0:
    print("the number is even")
else:
    print("the number is odd")
# Out:
# the number is even

# %%
def even_or_odd(num):
    """This function finds even or odd"""
    if num%2==0:
        print("the number is even")
    else:
        print("the number is odd")

# %%
## Call this function
even_or_odd(21)
# Out:
# the number is odd

# %%
## function with multiple parameters

def add(a,b):
    return a+b

result=add(2,4)
print(result)
# Out:
# 6

# %%
## Default Parameters

def greet(name):
    print(f"Hello {name} Welcome To the paradise")

greet("Uzair Khan")
# Out:
# Hello Uzair Khan Welcome To the paradise

# %%
def greet(name="Guest"):
    print(f"Hello {name} Welcome To the paradise")

greet("Amir khan")
# Out:
# Hello Amir khan Welcome To the paradise

# %%
### Variable Length Arguments
## Positional And Keywords arguments

def print_numbers(*args):
    for number in args:
        print(number)

# %%
try:
	print_numbers(1,2,3,4,5,6,7,8,"Uzair")
except NameError:
	# define fallback if print_numbers isn't defined yet (avoids duplicate definitions)
	def print_numbers(*args):
		for number in args:
			print(number)
	print_numbers(1,2,3,4,5,6,7,8,"Uzair")
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# Uzair

# %%
## Positional arguments
def print_numbers(*args):
    for number in args:
        print(number)

# %%
print_numbers(1,2,3,4,5,6,7,8,"Uzair")
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# Uzair

# %%
### Keywords Arguments

def print_details(**kwargs):
    for key,value in kwargs.items():
        print(f"{key}:{value}")

# %%
print_details(name="Uzair",age="23",country="Pakistan")
# Out:
# name:Uzair
# age:23
# country:Pakistan

# %%
def print_details(*args,**kwargs):
    for val in args:
        print(f" Positional argument :{val}")
    
    for key,value in kwargs.items():
        print(f"{key}:{value}")

# %%
print_details(1,2,3,4,"Uzair",name="Khan",age="23",country="Pakistan")
# Out:
#  Positional argument :1
#  Positional argument :2
#  Positional argument :3
#  Positional argument :4
#  Positional argument :Uzair
# name:Khan
# age:23
# country:Pakistan

# %%
### Return statements
def multiply(a,b):
    return a*b

multiply(2,3)

# %%
### Return multiple parameters
def multiply(a,b):
    return a*b,a

multiply(2,3)
